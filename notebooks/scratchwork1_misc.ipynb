# %% [markdown]
# # Miscellaneous Testing

# %%
from hyprat import Hy
from IPython.display import display, Math

# %%
q0 = Hy.random(2)
q0
# Out:
# Hy(Hy('-1/4', '1/6'), Hy('1', '-9/2'))

# %%
print(q0)
# Out:
# (-1/4+1/6i+j-9/2k)

# %%
q0.latex()
# Out:
# '-\\frac{1}{4}+\\frac{1}{6}i+j-\\frac{9}{2}k'

# %%
def latexp(hy):
    display(Math(hy.latex()))

# %%
latexp(q0)
# Out:
# $\displaystyle -\frac{1}{4}+\frac{1}{6}i+j-\frac{9}{2}k$

# %%
o0 = Hy.random(3)
o0str = str(o0)
print(o0str)
latexp(o0)
# Out:
# (-2+1/6i+1/3j-3/2k+8/3L+5/4iL+jL-kL)
# $\displaystyle -2+\frac{1}{6}i+\frac{1}{3}j-\frac{3}{2}k+\frac{8}{3}L+\frac{5}{4}iL+jL-kL$

# %%
o0p = Hy.parse(o0str)
o0p
# Out:
# Hy(Hy(Hy('-2', '1/6'), Hy('1/3', '-3/2')), Hy(Hy('8/3', '5/4'), Hy('1', '-1')))

# %%
latexp(o0p)
# Out:
# $\displaystyle -2+\frac{1}{6}i+\frac{1}{3}j-\frac{3}{2}k+\frac{8}{3}L+\frac{5}{4}iL+jL-kL$

# %%
u3 = Hy.units(3)
u3
# Out:
# {'1': Hy(Hy(Hy('1', '0'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  '-1': Hy(Hy(Hy('-1', '0'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  'i': Hy(Hy(Hy('0', '1'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  '-i': Hy(Hy(Hy('0', '-1'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  'j': Hy(Hy(Hy('0', '0'), Hy('1', '0')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  '-j': Hy(Hy(Hy('0', '0'), Hy('-1', '0')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  'k': Hy(Hy(Hy('0', '0'), Hy('0', '1')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  '-k': Hy(Hy(Hy('0', '0'), Hy('0', '-1')), Hy(Hy('0', '0'), Hy('0', '0'))),
#  'L': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('1', '0'), Hy('0', '0'))),
#  '-L': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('-1', '0'), Hy('0', '0'))),
#  'iL': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('0', '1'), Hy('0', '0'))),
#  '-iL': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('0', '-1'), Hy('0', '0'))),
#  'jL': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('1', '0'))),
#  '-jL': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('-1', '0'))),
#  'kL': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('0', '1'))),
#  '-kL': Hy(Hy(Hy('0', '0'), Hy('0', '0')), Hy(Hy('0', '0'), Hy('0', '-1')))}

# %%
def find(unit, units):
    for key, val in units.items():
        if unit == val:
            return key
    else:
        return False
